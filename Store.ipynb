-- %% [markdown]
-- # [Store]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Store]    Script Date: 15.05.2023 16:30:04 ******/
CREATE DATABASE [Store]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Store', FILENAME = N'C:\sqlserver\Shop1.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Store_log', FILENAME = N'C:\sqlserver\Shop1_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Store] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Store].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Store] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Store] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Store] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Store] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Store] SET ARITHABORT OFF 
GO
ALTER DATABASE [Store] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Store] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Store] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Store] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Store] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Store] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Store] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Store] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Store] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Store] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Store] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Store] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Store] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Store] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Store] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Store] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Store] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Store] SET RECOVERY FULL 
GO
ALTER DATABASE [Store] SET  MULTI_USER 
GO
ALTER DATABASE [Store] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Store] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Store] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Store] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Store] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Store] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Store', N'ON'
GO
ALTER DATABASE [Store] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Address]

-- %%
USE [Store]
GO

-- %%
/****** Object:  Table [dbo].[Address]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Address](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[street] [nvarchar](50) NULL,
	[id_city] [int] NULL,
 CONSTRAINT [PK_Address] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Category]

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
 CONSTRAINT [PK_Category] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[City]

-- %%
/****** Object:  Table [dbo].[City]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[City](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[id_region] [int] NULL,
 CONSTRAINT [PK_City] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
/****** Object:  Table [dbo].[Country]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Country](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
 CONSTRAINT [PK_Country] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Delivery]

-- %%
/****** Object:  Table [dbo].[Delivery]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Delivery](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[id_product] [int] NULL,
	[id_supplier] [int] NULL,
	[price] [float] NULL,
	[quantity] [int] NULL,
	[date_of_delivery] [date] NULL,
 CONSTRAINT [PK_Delivery] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Markup]

-- %%
/****** Object:  Table [dbo].[Markup]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Markup](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[percent] [nvarchar](50) NULL,
 CONSTRAINT [PK_Markup] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Measurement]

-- %%
/****** Object:  Table [dbo].[Measurement]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Measurement](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[description] [nvarchar](50) NULL,
 CONSTRAINT [PK_Measurement] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Producer]

-- %%
/****** Object:  Table [dbo].[Producer]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Producer](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[id_address] [int] NULL,
 CONSTRAINT [PK_Producer] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[id] [int] NOT NULL,
	[name] [nvarchar](50) NULL,
	[id_category] [int] NULL,
	[id_producer] [int] NULL,
	[price] [float] NULL,
	[quantity] [int] NULL,
	[id_measurement] [int] NULL,
	[id_markup] [int] NULL,
 CONSTRAINT [PK_Product] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Region]

-- %%
/****** Object:  Table [dbo].[Region]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Region](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[id_country] [int] NULL,
 CONSTRAINT [PK_Region] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sale]

-- %%
/****** Object:  Table [dbo].[Sale]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sale](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[id_product] [int] NULL,
	[price] [float] NULL,
	[quantity] [int] NULL,
	[date_of_sale] [date] NULL,
 CONSTRAINT [PK_Sale] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Supplier]

-- %%
/****** Object:  Table [dbo].[Supplier]    Script Date: 15.05.2023 16:30:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Supplier](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[id_address] [int] NULL,
 CONSTRAINT [PK_Supplier] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Address]

-- %%
SET IDENTITY_INSERT [dbo].[Address] ON 
INSERT [dbo].[Address] ([id], [street], [id_city]) VALUES (1, N'Садовая ', 15)
INSERT [dbo].[Address] ([id], [street], [id_city]) VALUES (2, N'Гран-Виа', 16)
INSERT [dbo].[Address] ([id], [street], [id_city]) VALUES (3, N'Олстон', 17)
INSERT [dbo].[Address] ([id], [street], [id_city]) VALUES (4, N'Сен-Антуан', 18)
INSERT [dbo].[Address] ([id], [street], [id_city]) VALUES (5, N'Вали-Аср', 19)
SET IDENTITY_INSERT [dbo].[Address] OFF
GO

-- %% [markdown]
-- # [dbo].[Category]

-- %%
SET IDENTITY_INSERT [dbo].[Category] ON 
INSERT [dbo].[Category] ([id], [name]) VALUES (1, N'молочные изделия ')
INSERT [dbo].[Category] ([id], [name]) VALUES (2, N'алкогольные напитки ')
INSERT [dbo].[Category] ([id], [name]) VALUES (3, N'овощи и фрукты ')
INSERT [dbo].[Category] ([id], [name]) VALUES (4, N'сладкое ')
INSERT [dbo].[Category] ([id], [name]) VALUES (5, N'мясо')
SET IDENTITY_INSERT [dbo].[Category] OFF
GO

-- %% [markdown]
-- # [dbo].[City]

-- %%
SET IDENTITY_INSERT [dbo].[City] ON 
INSERT [dbo].[City] ([id], [name], [id_region]) VALUES (15, N'Одесса', 1)
INSERT [dbo].[City] ([id], [name], [id_region]) VALUES (16, N'Мадрид', 2)
INSERT [dbo].[City] ([id], [name], [id_region]) VALUES (17, N'Бостон', 3)
INSERT [dbo].[City] ([id], [name], [id_region]) VALUES (18, N'Марсель', 4)
INSERT [dbo].[City] ([id], [name], [id_region]) VALUES (19, N'Тегеран', 5)
SET IDENTITY_INSERT [dbo].[City] OFF
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
SET IDENTITY_INSERT [dbo].[Country] ON 
INSERT [dbo].[Country] ([id], [name]) VALUES (1, N'Украина ')
INSERT [dbo].[Country] ([id], [name]) VALUES (2, N'Испания')
INSERT [dbo].[Country] ([id], [name]) VALUES (3, N'Америка')
INSERT [dbo].[Country] ([id], [name]) VALUES (4, N'Франция ')
INSERT [dbo].[Country] ([id], [name]) VALUES (5, N'Иран')
SET IDENTITY_INSERT [dbo].[Country] OFF
GO

-- %% [markdown]
-- # [dbo].[Delivery]

-- %%
SET IDENTITY_INSERT [dbo].[Delivery] ON 
INSERT [dbo].[Delivery] ([id], [id_product], [id_supplier], [price], [quantity], [date_of_delivery]) VALUES (1, 1, 1, 20, 120, CAST(N'2022-10-04' AS Date))
INSERT [dbo].[Delivery] ([id], [id_product], [id_supplier], [price], [quantity], [date_of_delivery]) VALUES (2, 2, 2, 80, 100, CAST(N'2022-09-29' AS Date))
INSERT [dbo].[Delivery] ([id], [id_product], [id_supplier], [price], [quantity], [date_of_delivery]) VALUES (3, 3, 3, 360, 50, CAST(N'0202-10-16' AS Date))
INSERT [dbo].[Delivery] ([id], [id_product], [id_supplier], [price], [quantity], [date_of_delivery]) VALUES (4, 4, 4, 40, 70, CAST(N'2024-12-30' AS Date))
INSERT [dbo].[Delivery] ([id], [id_product], [id_supplier], [price], [quantity], [date_of_delivery]) VALUES (5, 5, 5, 70, 110, CAST(N'2022-10-07' AS Date))
SET IDENTITY_INSERT [dbo].[Delivery] OFF
GO

-- %% [markdown]
-- # [dbo].[Markup]

-- %%
SET IDENTITY_INSERT [dbo].[Markup] ON 
INSERT [dbo].[Markup] ([id], [name], [percent]) VALUES (1, N'яблоко', N'2')
INSERT [dbo].[Markup] ([id], [name], [percent]) VALUES (2, N'говядина ', N'5')
INSERT [dbo].[Markup] ([id], [name], [percent]) VALUES (3, N'виски', N'7')
INSERT [dbo].[Markup] ([id], [name], [percent]) VALUES (4, N'сникерс ', N'3')
INSERT [dbo].[Markup] ([id], [name], [percent]) VALUES (5, N'сыр', N'4')
SET IDENTITY_INSERT [dbo].[Markup] OFF
GO

-- %% [markdown]
-- # [dbo].[Measurement]

-- %%
SET IDENTITY_INSERT [dbo].[Measurement] ON 
INSERT [dbo].[Measurement] ([id], [name], [description]) VALUES (1, N'яблоко', N'килограммы ')
INSERT [dbo].[Measurement] ([id], [name], [description]) VALUES (2, N'говядина ', N'килограммы')
INSERT [dbo].[Measurement] ([id], [name], [description]) VALUES (3, N'виски', N'литры')
INSERT [dbo].[Measurement] ([id], [name], [description]) VALUES (4, N'сникерс', N'коробки')
INSERT [dbo].[Measurement] ([id], [name], [description]) VALUES (5, N'сыр', N'килограммы')
SET IDENTITY_INSERT [dbo].[Measurement] OFF
GO

-- %% [markdown]
-- # [dbo].[Producer]

-- %%
SET IDENTITY_INSERT [dbo].[Producer] ON 
INSERT [dbo].[Producer] ([id], [name], [id_address]) VALUES (1, N'огород ', 4)
INSERT [dbo].[Producer] ([id], [name], [id_address]) VALUES (2, N'завод ', 3)
INSERT [dbo].[Producer] ([id], [name], [id_address]) VALUES (3, N'компания ', 5)
INSERT [dbo].[Producer] ([id], [name], [id_address]) VALUES (4, N'сад ', 1)
INSERT [dbo].[Producer] ([id], [name], [id_address]) VALUES (5, N'фабрика', 2)
SET IDENTITY_INSERT [dbo].[Producer] OFF
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
INSERT [dbo].[Product] ([id], [name], [id_category], [id_producer], [price], [quantity], [id_measurement], [id_markup]) VALUES (1, N'яблоко', 3, 4, 20, 120, 1, 1)
INSERT [dbo].[Product] ([id], [name], [id_category], [id_producer], [price], [quantity], [id_measurement], [id_markup]) VALUES (2, N'говядина ', 5, 2, 80, 100, 2, 2)
INSERT [dbo].[Product] ([id], [name], [id_category], [id_producer], [price], [quantity], [id_measurement], [id_markup]) VALUES (3, N'виски', 2, 5, 360, 50, 3, 3)
INSERT [dbo].[Product] ([id], [name], [id_category], [id_producer], [price], [quantity], [id_measurement], [id_markup]) VALUES (4, N'сникерс ', 4, 5, 40, 70, 4, 4)
INSERT [dbo].[Product] ([id], [name], [id_category], [id_producer], [price], [quantity], [id_measurement], [id_markup]) VALUES (5, N'сыр', 1, 1, 70, 110, 5, 5)
GO

-- %% [markdown]
-- # [dbo].[Region]

-- %%
SET IDENTITY_INSERT [dbo].[Region] ON 
INSERT [dbo].[Region] ([id], [name], [id_country]) VALUES (1, N'одесская', 1)
INSERT [dbo].[Region] ([id], [name], [id_country]) VALUES (2, N'мадрид', 2)
INSERT [dbo].[Region] ([id], [name], [id_country]) VALUES (3, N'массачусетс', 3)
INSERT [dbo].[Region] ([id], [name], [id_country]) VALUES (4, N'альпы', 4)
INSERT [dbo].[Region] ([id], [name], [id_country]) VALUES (5, N'тегеран', 5)
SET IDENTITY_INSERT [dbo].[Region] OFF
GO

-- %% [markdown]
-- # [dbo].[Sale]

-- %%
SET IDENTITY_INSERT [dbo].[Sale] ON 
INSERT [dbo].[Sale] ([id], [id_product], [price], [quantity], [date_of_sale]) VALUES (1, 1, 20, 120, CAST(N'2022-05-19' AS Date))
INSERT [dbo].[Sale] ([id], [id_product], [price], [quantity], [date_of_sale]) VALUES (2, 2, 80, 100, CAST(N'2022-05-10' AS Date))
INSERT [dbo].[Sale] ([id], [id_product], [price], [quantity], [date_of_sale]) VALUES (3, 3, 360, 50, CAST(N'2022-05-21' AS Date))
INSERT [dbo].[Sale] ([id], [id_product], [price], [quantity], [date_of_sale]) VALUES (4, 4, 40, 70, CAST(N'2022-05-05' AS Date))
INSERT [dbo].[Sale] ([id], [id_product], [price], [quantity], [date_of_sale]) VALUES (5, 5, 70, 110, CAST(N'2022-05-13' AS Date))
SET IDENTITY_INSERT [dbo].[Sale] OFF
GO

-- %% [markdown]
-- # [dbo].[Supplier]

-- %%
SET IDENTITY_INSERT [dbo].[Supplier] ON 
INSERT [dbo].[Supplier] ([id], [name], [id_address]) VALUES (1, N'Эпп', 3)
INSERT [dbo].[Supplier] ([id], [name], [id_address]) VALUES (2, N'Мит', 2)
INSERT [dbo].[Supplier] ([id], [name], [id_address]) VALUES (3, N'Алхо', 1)
INSERT [dbo].[Supplier] ([id], [name], [id_address]) VALUES (4, N'Свит', 5)
INSERT [dbo].[Supplier] ([id], [name], [id_address]) VALUES (5, N'Мил', 4)
SET IDENTITY_INSERT [dbo].[Supplier] OFF
GO

-- %% [markdown]
-- # [FK_Address_City]

-- %%
ALTER TABLE [dbo].[Address]  WITH CHECK ADD  CONSTRAINT [FK_Address_City] FOREIGN KEY([id_city])
REFERENCES [dbo].[City] ([id])
GO
ALTER TABLE [dbo].[Address] CHECK CONSTRAINT [FK_Address_City]
GO

-- %% [markdown]
-- # [FK_City_Region]

-- %%
ALTER TABLE [dbo].[City]  WITH CHECK ADD  CONSTRAINT [FK_City_Region] FOREIGN KEY([id_region])
REFERENCES [dbo].[Region] ([id])
GO
ALTER TABLE [dbo].[City] CHECK CONSTRAINT [FK_City_Region]
GO

-- %% [markdown]
-- # [FK_Delivery_Product]

-- %%
ALTER TABLE [dbo].[Delivery]  WITH CHECK ADD  CONSTRAINT [FK_Delivery_Product] FOREIGN KEY([id_product])
REFERENCES [dbo].[Product] ([id])
GO
ALTER TABLE [dbo].[Delivery] CHECK CONSTRAINT [FK_Delivery_Product]
GO

-- %% [markdown]
-- # [FK_Delivery_Supplier]

-- %%
ALTER TABLE [dbo].[Delivery]  WITH CHECK ADD  CONSTRAINT [FK_Delivery_Supplier] FOREIGN KEY([id_supplier])
REFERENCES [dbo].[Supplier] ([id])
GO
ALTER TABLE [dbo].[Delivery] CHECK CONSTRAINT [FK_Delivery_Supplier]
GO

-- %% [markdown]
-- # [FK_Producer_Address]

-- %%
ALTER TABLE [dbo].[Producer]  WITH CHECK ADD  CONSTRAINT [FK_Producer_Address] FOREIGN KEY([id_address])
REFERENCES [dbo].[Address] ([id])
GO
ALTER TABLE [dbo].[Producer] CHECK CONSTRAINT [FK_Producer_Address]
GO

-- %% [markdown]
-- # [FK_Product_Category]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_Category] FOREIGN KEY([id_category])
REFERENCES [dbo].[Category] ([id])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_Category]
GO

-- %% [markdown]
-- # [FK_Product_Markup]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_Markup] FOREIGN KEY([id_markup])
REFERENCES [dbo].[Markup] ([id])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_Markup]
GO

-- %% [markdown]
-- # [FK_Product_Measurement]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_Measurement] FOREIGN KEY([id_measurement])
REFERENCES [dbo].[Measurement] ([id])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_Measurement]
GO

-- %% [markdown]
-- # [FK_Product_Producer]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_Producer] FOREIGN KEY([id_producer])
REFERENCES [dbo].[Producer] ([id])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_Producer]
GO

-- %% [markdown]
-- # [FK_Region_Country]

-- %%
ALTER TABLE [dbo].[Region]  WITH CHECK ADD  CONSTRAINT [FK_Region_Country] FOREIGN KEY([id_country])
REFERENCES [dbo].[Country] ([id])
GO
ALTER TABLE [dbo].[Region] CHECK CONSTRAINT [FK_Region_Country]
GO

-- %% [markdown]
-- # [FK_Sale_Product]

-- %%
ALTER TABLE [dbo].[Sale]  WITH CHECK ADD  CONSTRAINT [FK_Sale_Product] FOREIGN KEY([id_product])
REFERENCES [dbo].[Product] ([id])
GO
ALTER TABLE [dbo].[Sale] CHECK CONSTRAINT [FK_Sale_Product]
GO

-- %% [markdown]
-- # [FK_Supplier_Address]

-- %%
ALTER TABLE [dbo].[Supplier]  WITH CHECK ADD  CONSTRAINT [FK_Supplier_Address] FOREIGN KEY([id_address])
REFERENCES [dbo].[Address] ([id])
GO
ALTER TABLE [dbo].[Supplier] CHECK CONSTRAINT [FK_Supplier_Address]
GO

-- %% [markdown]
-- # [Store]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Store] SET  READ_WRITE 
GO
